# %% [markdown]
# <a href="https://colab.research.google.com/github/gagabriela2787/Grupo7ISPC/blob/gabriela/grupo7caceres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plb
import csv

# %%
df = pd.read_csv('/nacidos-vivos-registrados-2018_deis.csv')

# %%
df.head(40)
# Out:
#     jurisdiccion_de_residencia_id jurisdiccion_de_residencia_nombre  \
# 0                              34                           Formosa
# 1                               2       Ciudad Aut. de Buenos Aires
# 2                               6                      Buenos Aires
# 3                              82                          Santa Fe
# 4                              74                          San Luis
# 5                              99             Lugar no especificado
# 6                              66                             Salta
# 7                               6                      Buenos Aires
# 8                              58                           Neuquén
# 9                              62                         Río Negro
# 10                              6                      Buenos Aires
# 11                             54                          Misiones
# 12                             90                           Tucumán
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30099 entries, 0 to 30098
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   jurisdiccion_de_residencia_id       30099 non-null  int64
#  1   jurisdiccion_de_residencia_nombre   30099 non-null  object
#  2   tipo_de_parto_id                    30099 non-null  int64
#  3   tipo_de_parto_nombre                30099 non-null  object
#  4   sexo                                30099 non-null  int64
#  5   sexo_nombre                         30099 non-null  object
#  6   edad_de_la_madre_grupos_id          30099 non-null  int64
#  7   edad_de_la_madre_grupos_nombre      30099 non-null  object
#  8   semanas_de_gestacion_id             30099 non-null  int64
#  9   semanas_de_gestacion_nombre         30099 non-null  object
#  10  instruccion_de_la_madre_id          30099 non-null  int64
# ...

# %%
df.columns.values
# Out:
# array(['jurisdiccion_de_residencia_id',
#        'jurisdiccion_de_residencia_nombre', 'tipo_de_parto_id',
#        'tipo_de_parto_nombre', 'sexo', 'sexo_nombre',
#        'edad_de_la_madre_grupos_id', 'edad_de_la_madre_grupos_nombre',
#        'semanas_de_gestacion_id', 'semanas_de_gestacion_nombre',
#        'instruccion_de_la_madre_id', 'instruccion_de_la_madre_nombre',
#        'Intervalos_de_peso_al_nacer_id',
#        'intervalos_de_peso_al_nacer_nombre', 'cantidad_nacimientos'],
#       dtype=object)

# %%
df.dtypes
# Out:
# jurisdiccion_de_residencia_id          int64
# jurisdiccion_de_residencia_nombre     object
# tipo_de_parto_id                       int64
# tipo_de_parto_nombre                  object
# sexo                                   int64
# sexo_nombre                           object
# edad_de_la_madre_grupos_id             int64
# edad_de_la_madre_grupos_nombre        object
# semanas_de_gestacion_id                int64
# semanas_de_gestacion_nombre           object
# instruccion_de_la_madre_id             int64
# instruccion_de_la_madre_nombre        object
# Intervalos_de_peso_al_nacer_id         int64
# intervalos_de_peso_al_nacer_nombre    object
# cantidad_nacimientos                   int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# jurisdiccion_de_residencia_id         0
# jurisdiccion_de_residencia_nombre     0
# tipo_de_parto_id                      0
# tipo_de_parto_nombre                  0
# sexo                                  0
# sexo_nombre                           0
# edad_de_la_madre_grupos_id            0
# edad_de_la_madre_grupos_nombre        0
# semanas_de_gestacion_id               0
# semanas_de_gestacion_nombre           0
# instruccion_de_la_madre_id            0
# instruccion_de_la_madre_nombre        0
# Intervalos_de_peso_al_nacer_id        0
# intervalos_de_peso_al_nacer_nombre    0
# cantidad_nacimientos                  0
# dtype: int64

# %%
#  Visualizar a traves de un grafico scatter la relacionn entre las columnas jurisdiccion_de_residencia_nombre y
#  (eje x) y edad_de_la_madre_grupos_nombre (eje y)

fig, ax = plb.subplots(figsize=(20,20))
ax.scatter(x = df['cantidad_nacimientos'],y = df['jurisdiccion_de_residencia_nombre'],color="pink",alpha= 0.6)

plb.xlabel("cantidad_nacimientos")
plb.ylabel("jurisdiccion_de_residencia_nombre")

plb.show()
