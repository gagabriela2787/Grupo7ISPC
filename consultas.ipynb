# %%
import pandas as pd

# %%
df = pd.read_csv('nacidos-vivos-registrados-2018_deis.csv',index_col=0)

# %%
df.head()
# Out:
#                               jurisdiccion_de_residencia_nombre  \
# jurisdiccion_de_residencia_id
# 34                                                      Formosa
# 2                                   Ciudad Aut. de Buenos Aires
# 6                                                  Buenos Aires
# 82                                                     Santa Fe
# 74                                                     San Luis
#
#                                tipo_de_parto_id tipo_de_parto_nombre  sexo  \
# jurisdiccion_de_residencia_id
# 34                                            1               Simple     2
# 2                                             1               Simple     1
# 6                                             1               Simple     1
# 82                                            1               Simple     2
# 74                                            1               Simple     1
#
# ...

# %%
df.sample(20) #ver 20 datos aleatorios
# Out:
#                               jurisdiccion_de_residencia_nombre  \
# jurisdiccion_de_residencia_id
# 62                                                    Río Negro
# 70                                                     San Juan
# 86                                          Santiago del Estero
# 90                                                      Tucumán
# 82                                                     Santa Fe
# 62                                                    Río Negro
# 22                                                        Chaco
# 86                                          Santiago del Estero
# 62                                                    Río Negro
# 30                                                   Entre Ríos
# 78                                                   Santa Cruz
# 26                                                       Chubut
# 82                                                     Santa Fe
# ...

# %%
parto =df.tipo_de_parto_nombre.value_counts()

# %%
parto.plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='tipo_de_parto_nombre'>

# %%
df.groupby('jurisdiccion_de_residencia_nombre').size()
# Out:
# jurisdiccion_de_residencia_nombre
# Buenos Aires                   4320
# Catamarca                       802
# Chaco                          1554
# Chubut                          743
# Ciudad Aut. de Buenos Aires    1828
# Corrientes                     1629
# Córdoba                        1597
# Entre Ríos                     1300
# Formosa                         924
# Jujuy                           859
# La Pampa                        520
# La Rioja                        616
# Lugar no especificado           646
# Mendoza                        1185
# Misiones                       1363
# Neuquén                         776
# Otro país                       132
# Río Negro                       913
# Salta                          1392
# San Juan                        832
# San Luis                        834
# Santa Cruz                      518
# Santa Fe                       1699
# Santiago del Estero            1174
# Tierra del Fuego                402
# ...
